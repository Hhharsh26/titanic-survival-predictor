# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.9 MB 2.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.3/8.9 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.9 MB 2.8 MB/s eta 0:00:03
#    ------------ --------------------------- 2.9/8.9 MB 3.0 MB/s eta 0:00:03
#    ----------------- ---------------------- 3.9/8.9 MB 3.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.0/8.9 MB 3.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.3/8.9 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.6/8.9 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 8.9/8.9 MB 4.4 MB/s  0:00:02
# ...
#    ---------------------------------------- 0.0/41.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/41.3 MB 6.7 MB/s eta 0:00:06
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
print ("hi")

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestClassifier
# Out:
# hi
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 9
#       6 get_ipython().run_line_magic('matplotlib', 'inline')
#       7 print ("hi")
# ----> 9 from sklearn.model_selection import train_test_split
#      10 from sklearn.compose import ColumnTransformer
#      11 from sklearn.pipeline import Pipeline
#
# File c:\Users\HP\OneDrive\Desktop\titanic\.venv\lib\site-packages\sklearn\__init__.py:73
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from . import (  # noqa: F401 E402
# ...

# %%
print("hi")
# Out:
# hi

# %%
train_df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\titanic\\dataset\\train.csv")
test_df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\titanic\\dataset\\test.csv")

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_df.shape
# Out:
# (418, 11)

# %%
train_df.info()
train_df.isnull().sum()
train_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
features=["Pclass","Sex","SibSp","Parch","Embarked"]
x=train_df[features]
y=train_df["Survived"]

x_test=test_df[features]

# %%
x.head()
y.head()
#x_test.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64
